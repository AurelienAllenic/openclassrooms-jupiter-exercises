# %%
import numpy as np
import pandas as pd

notes = pd.read_csv('notes.csv')
notes['matiere'].unique()
math_average = notes.loc[notes['matiere'] == 'mathematiques', 'note'].mean()
print(math_average)
# Out:
# nan
